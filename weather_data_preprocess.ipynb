# %% [markdown]
# - 时间跨度
#     - 历史数据中包含`('2017-01-01 00:00:00', '2018-03-27 05:00:00')`的天气数据
#     - API 下载数据中包含 `'2017-04-01 00:00:00'` 以后的数据
#     - 拟使用四月的数据作为 dev set，历史数据作为训练集

# %%
import numpy as np
import datetime
import pandas as pd
from utils.weather_data_util import load_bj_grid_meo_data

# %% [markdown]
# ### 1. 首先加载使用到的 meo 数据

# %%
near_stations = {'aotizhongxin_aq': 'beijing_grid_304',
 'badaling_aq': 'beijing_grid_224',
 'beibuxinqu_aq': 'beijing_grid_263',
 'daxing_aq': 'beijing_grid_301',
 'dingling_aq': 'beijing_grid_265',
 'donggaocun_aq': 'beijing_grid_452',
 'dongsi_aq': 'beijing_grid_303',
 'dongsihuan_aq': 'beijing_grid_324',
 'fangshan_aq': 'beijing_grid_238',
 'fengtaihuayuan_aq': 'beijing_grid_282',
 'guanyuan_aq': 'beijing_grid_282',
 'gucheng_aq': 'beijing_grid_261',
 'huairou_aq': 'beijing_grid_349',
 'liulihe_aq': 'beijing_grid_216',
 'mentougou_aq': 'beijing_grid_240',
 'miyun_aq': 'beijing_grid_392',
 'miyunshuiku_aq': 'beijing_grid_414',
 'nansanhuan_aq': 'beijing_grid_303',
 'nongzhanguan_aq': 'beijing_grid_324',
 'pingchang_aq': 'beijing_grid_264',
 'pinggu_aq': 'beijing_grid_452',
 'qianmen_aq': 'beijing_grid_303',
 'shunyi_aq': 'beijing_grid_368',
 'tiantan_aq': 'beijing_grid_303',
 'tongzhou_aq': 'beijing_grid_366',
 'wanliu_aq': 'beijing_grid_283',
 'wanshouxigong_aq': 'beijing_grid_303',
 'xizhimenbei_aq': 'beijing_grid_283',
 'yanqin_aq': 'beijing_grid_225',
 'yizhuang_aq': 'beijing_grid_323',
 'yongdingmennei_aq': 'beijing_grid_303',
 'yongledian_aq': 'beijing_grid_385',
 'yufa_aq': 'beijing_grid_278',
 'yungang_aq': 'beijing_grid_239',
 'zhiwuyuan_aq': 'beijing_grid_262'}

# %%
# bj_meo_stations : meo_station as key and df as value 
bj_grid_meo_dataset, stations, bj_meo_stations = load_bj_grid_meo_data(near_stations)

# %%
bj_meo_stations['zhiwuyuan_aq'].head(1000)
# Out:
#                      zhiwuyuan_aq_temperature  zhiwuyuan_aq_pressure  \
# time
# 2017-01-01 00:00:00                     -6.01                1003.24
# 2017-01-01 01:00:00                     -3.19                1003.12
# 2017-01-01 02:00:00                     -0.37                1003.00
# 2017-01-01 03:00:00                      2.45                1002.89
# 2017-01-01 04:00:00                      3.55                1002.25
# 2017-01-01 05:00:00                      4.64                1001.61
# 2017-01-01 06:00:00                      5.74                1000.97
# 2017-01-01 07:00:00                      3.30                1000.94
# 2017-01-01 08:00:00                      0.86                1000.91
# 2017-01-01 09:00:00                     -1.58                1000.88
# 2017-01-01 10:00:00                     -1.86                1001.08
# 2017-01-01 11:00:00                     -2.13                1001.27
# 2017-01-01 12:00:00                     -2.40                1001.47
# 2017-01-01 13:00:00                     -2.09                1001.72
# 2017-01-01 14:00:00                     -1.78                1001.97
# 2017-01-01 15:00:00                     -1.48                1002.21
# 2017-01-01 16:00:00                     -1.52                1002.37
# 2017-01-01 17:00:00                     -1.57                1002.52
# 2017-01-01 18:00:00                     -1.62                1002.67
# 2017-01-01 19:00:00                     -1.95                1002.88
# 2017-01-01 20:00:00                     -2.29                1003.09
# 2017-01-01 21:00:00                     -2.62                1003.30
# 2017-01-01 22:00:00                     -2.87                1003.69
# 2017-01-01 23:00:00                     -3.12                1004.09
# 2017-01-02 00:00:00                     -3.36                1004.49
# 2017-01-02 01:00:00                     -1.19                1004.67
# 2017-01-02 02:00:00                      0.98                1004.85
# 2017-01-02 03:00:00                      3.15                1005.03
# 2017-01-02 04:00:00                      4.00                1004.51
# 2017-01-02 05:00:00                      4.85                1003.99
# ...                                       ...                    ...
# 2017-02-10 10:00:00                     -0.81                1005.87
# 2017-02-10 11:00:00                     -2.26                1006.11
# 2017-02-10 12:00:00                     -3.72                1006.35
# 2017-02-10 13:00:00                     -4.00                1006.48
# 2017-02-10 14:00:00                     -4.29                1006.61
# 2017-02-10 15:00:00                     -4.57                1006.74
# 2017-02-10 16:00:00                     -4.81                1006.92
# 2017-02-10 17:00:00                     -5.05                1007.10
# 2017-02-10 18:00:00                     -5.29                1007.29
# 2017-02-10 19:00:00                     -5.46                1007.20
# 2017-02-10 20:00:00                     -5.64                1007.11
# 2017-02-10 21:00:00                     -5.81                1007.03
# 2017-02-10 22:00:00                     -5.67                1007.18
# 2017-02-10 23:00:00                     -5.53                1007.32
# 2017-02-11 00:00:00                     -5.38                1007.47
# 2017-02-11 01:00:00                     -2.76                1007.27
# 2017-02-11 02:00:00                     -0.13                1007.06
# 2017-02-11 03:00:00                      2.50                1006.86
# 2017-02-11 04:00:00                      3.91                1006.17
# 2017-02-11 05:00:00                      5.31                1005.49
# 2017-02-11 06:00:00                      6.71                1004.81
# 2017-02-11 07:00:00                      5.35                1004.57
# 2017-02-11 08:00:00                      3.99                1004.33
# 2017-02-11 09:00:00                      2.62                1004.09
# 2017-02-11 10:00:00                      0.90                1004.45
# 2017-02-11 11:00:00                     -0.82                1004.80
# 2017-02-11 12:00:00                     -2.55                1005.15
# 2017-02-11 13:00:00                     -2.48                1005.04
# 2017-02-11 14:00:00                     -2.41                1004.93
# 2017-02-11 15:00:00                     -2.34                1004.82
#
#                      zhiwuyuan_aq_humidity  zhiwuyuan_aq_wind_direction  \
# time
# 2017-01-01 00:00:00                  69.97                       129.93
# 2017-01-01 01:00:00                  58.66                       147.40
# 2017-01-01 02:00:00                  47.35                       166.69
# 2017-01-01 03:00:00                  36.04                       183.97
# 2017-01-01 04:00:00                  33.61                       154.96
# 2017-01-01 05:00:00                  31.18                       141.93
# 2017-01-01 06:00:00                  28.74                       135.24
# 2017-01-01 07:00:00                  35.78                       144.13
# 2017-01-01 08:00:00                  42.82                       153.54
# 2017-01-01 09:00:00                  49.86                       162.99
# 2017-01-01 10:00:00                  49.94                       179.98
# 2017-01-01 11:00:00                  50.02                       236.70
# 2017-01-01 12:00:00                  50.11                       288.03
# 2017-01-01 13:00:00                  47.84                       309.10
# 2017-01-01 14:00:00                  45.56                       316.51
# 2017-01-01 15:00:00                  43.29                       320.17
# 2017-01-01 16:00:00                  43.37                       320.94
# 2017-01-01 17:00:00                  43.44                       321.54
# 2017-01-01 18:00:00                  43.51                       322.03
# 2017-01-01 19:00:00                  44.26                       322.18
# 2017-01-01 20:00:00                  45.02                       322.35
# 2017-01-01 21:00:00                  45.77                       322.52
# 2017-01-01 22:00:00                  45.65                       321.57
# 2017-01-01 23:00:00                  45.54                       320.46
# 2017-01-02 00:00:00                  45.42                       319.12
# 2017-01-02 01:00:00                  38.97                       319.29
# 2017-01-02 02:00:00                  32.51                       319.53
# 2017-01-02 03:00:00                  26.05                       319.90
# 2017-01-02 04:00:00                  24.81                       305.83
# 2017-01-02 05:00:00                  23.56                       169.35
# ...                                    ...                          ...
# 2017-02-10 10:00:00                  19.36                       315.20
# 2017-02-10 11:00:00                  22.50                       312.20
# 2017-02-10 12:00:00                  25.65                       308.19
# 2017-02-10 13:00:00                  27.73                       308.67
# 2017-02-10 14:00:00                  29.81                       309.23
# 2017-02-10 15:00:00                  31.89                       309.88
# 2017-02-10 16:00:00                  34.00                       311.09
# 2017-02-10 17:00:00                  36.11                       312.29
# 2017-02-10 18:00:00                  38.23                       313.50
# 2017-02-10 19:00:00                  40.35                       314.38
# 2017-02-10 20:00:00                  42.48                       315.29
# 2017-02-10 21:00:00                  44.61                       316.23
# 2017-02-10 22:00:00                  44.39                       317.13
# 2017-02-10 23:00:00                  44.17                       318.06
# 2017-02-11 00:00:00                  43.95                       319.02
# 2017-02-11 01:00:00                  36.93                       319.40
# 2017-02-11 02:00:00                  29.92                       319.78
# 2017-02-11 03:00:00                  22.91                       320.13
# 2017-02-11 04:00:00                  20.58                       318.78
# 2017-02-11 05:00:00                  18.26                       317.64
# 2017-02-11 06:00:00                  15.94                       316.68
# 2017-02-11 07:00:00                  18.52                       310.08
# 2017-02-11 08:00:00                  21.11                       296.82
# 2017-02-11 09:00:00                  23.69                       265.73
# 2017-02-11 10:00:00                  27.36                       266.85
# 2017-02-11 11:00:00                  31.03                       268.03
# 2017-02-11 12:00:00                  34.69                       269.26
# 2017-02-11 13:00:00                  34.67                       287.97
# 2017-02-11 14:00:00                  34.64                       301.30
# 2017-02-11 15:00:00                  34.61                       310.36
#
#                      zhiwuyuan_aq_wind_speed/kph
# time
# 2017-01-01 00:00:00                         1.51
# 2017-01-01 01:00:00                         1.37
# 2017-01-01 02:00:00                         1.38
# 2017-01-01 03:00:00                         1.53
# 2017-01-01 04:00:00                         2.27
# 2017-01-01 05:00:00                         3.28
# 2017-01-01 06:00:00                         4.39
# 2017-01-01 07:00:00                         4.21
# 2017-01-01 08:00:00                         4.14
# 2017-01-01 09:00:00                         4.19
# 2017-01-01 10:00:00                         2.41
# 2017-01-01 11:00:00                         1.47
# 2017-01-01 12:00:00                         2.58
# 2017-01-01 13:00:00                         4.76
# 2017-01-01 14:00:00                         7.18
# 2017-01-01 15:00:00                         9.65
# 2017-01-01 16:00:00                        10.97
# 2017-01-01 17:00:00                        12.29
# 2017-01-01 18:00:00                        13.61
# 2017-01-01 19:00:00                        13.29
# 2017-01-01 20:00:00                        12.96
# 2017-01-01 21:00:00                        12.63
# 2017-01-01 22:00:00                        11.66
# 2017-01-01 23:00:00                        10.69
# 2017-01-02 00:00:00                         9.73
# 2017-01-02 01:00:00                         8.27
# 2017-01-02 02:00:00                         6.82
# 2017-01-02 03:00:00                         5.37
# 2017-01-02 04:00:00                         1.92
# 2017-01-02 05:00:00                         1.89
# ...                                          ...
# 2017-02-10 10:00:00                        17.50
# 2017-02-10 11:00:00                        15.26
# 2017-02-10 12:00:00                        13.07
# 2017-02-10 13:00:00                        12.19
# 2017-02-10 14:00:00                        11.31
# 2017-02-10 15:00:00                        10.42
# 2017-02-10 16:00:00                        10.41
# 2017-02-10 17:00:00                        10.39
# 2017-02-10 18:00:00                        10.39
# 2017-02-10 19:00:00                        10.22
# 2017-02-10 20:00:00                        10.06
# 2017-02-10 21:00:00                         9.90
# 2017-02-10 22:00:00                         9.75
# 2017-02-10 23:00:00                         9.60
# 2017-02-11 00:00:00                         9.45
# 2017-02-11 01:00:00                         9.66
# 2017-02-11 02:00:00                         9.87
# 2017-02-11 03:00:00                        10.07
# 2017-02-11 04:00:00                        11.04
# 2017-02-11 05:00:00                        12.02
# 2017-02-11 06:00:00                        13.00
# 2017-02-11 07:00:00                         9.63
# 2017-02-11 08:00:00                         6.52
# 2017-02-11 09:00:00                         4.27
# 2017-02-11 10:00:00                         4.17
# 2017-02-11 11:00:00                         4.07
# 2017-02-11 12:00:00                         3.98
# 2017-02-11 13:00:00                         4.57
# 2017-02-11 14:00:00                         5.53
# 2017-02-11 15:00:00                         6.69
#
# [1000 rows x 5 columns]

# %%
len(bj_meo_stations.keys())
# Out:
# 35

# %% [markdown]
# ### 2. 重复值分析

# %% [markdown]
# - 识别重复值的数量，并将重复值去掉
# - meo 数据中没有重复数据

# %%
for station in bj_meo_stations.keys() :
    
    df = bj_meo_stations[station].copy()
    length = df.shape[0]
    order = range(length)
    df['order'] = pd.Series(order, index=df.index)    
    
    
    df["time"] = df.index
    df.set_index("order", inplace=True)
    
    length_1 = df.shape[0]
    # print("重复值去除之前，共有数据数量", df.shape[0])
    
    used_times = []
    for index in df.index :
        time = df.loc[index]["time"]
        if time not in used_times :
            used_times.append(time)
        else : 
            df.drop([index], inplace=True)

    length_2 = df.shape[0]
    delta = length_1 - length_2
    # print("重复值去除之后，共有数据数量", df.shape[0])
    print("%s 重复数量 : %d" %(station, delta))
    
    df.set_index("time", inplace=True)
    bj_meo_stations[station] = df
# Out:
# miyunshuiku_aq 重复数量 : 0
# wanliu_aq 重复数量 : 0
# guanyuan_aq 重复数量 : 0
# fengtaihuayuan_aq 重复数量 : 0
# huairou_aq 重复数量 : 0
# liulihe_aq 重复数量 : 0
# wanshouxigong_aq 重复数量 : 0
# yizhuang_aq 重复数量 : 0
# fangshan_aq 重复数量 : 0
# zhiwuyuan_aq 重复数量 : 0
# pingchang_aq 重复数量 : 0
# dingling_aq 重复数量 : 0
# xizhimenbei_aq 重复数量 : 0
# aotizhongxin_aq 重复数量 : 0
# tiantan_aq 重复数量 : 0
# dongsi_aq 重复数量 : 0
# badaling_aq 重复数量 : 0
# shunyi_aq 重复数量 : 0
# dongsihuan_aq 重复数量 : 0
# gucheng_aq 重复数量 : 0
# donggaocun_aq 重复数量 : 0
# pinggu_aq 重复数量 : 0
# mentougou_aq 重复数量 : 0
# miyun_aq 重复数量 : 0
# nongzhanguan_aq 重复数量 : 0
# yufa_aq 重复数量 : 0
# daxing_aq 重复数量 : 0
# yongdingmennei_aq 重复数量 : 0
# qianmen_aq 重复数量 : 0
# beibuxinqu_aq 重复数量 : 0
# nansanhuan_aq 重复数量 : 0
# yongledian_aq 重复数量 : 0
# tongzhou_aq 重复数量 : 0
# yanqin_aq 重复数量 : 0
# yungang_aq 重复数量 : 0

# %% [markdown]
# ### 3. 缺失值分析

# %% [markdown]
# #### 3.1 局部缺失

# %% [markdown]
# 判断有没有局部缺失：没有局部缺失！

# %%
for station in bj_meo_stations.keys():
    df = bj_meo_stations[station]
    print(station, pd.isnull(df).any().any())
# Out:
# miyunshuiku_aq False
# wanliu_aq False
# guanyuan_aq False
# fengtaihuayuan_aq False
# huairou_aq False
# liulihe_aq False
# wanshouxigong_aq False
# yizhuang_aq False
# fangshan_aq False
# zhiwuyuan_aq False
# pingchang_aq False
# dingling_aq False
# xizhimenbei_aq False
# aotizhongxin_aq False
# tiantan_aq False
# dongsi_aq False
# badaling_aq False
# shunyi_aq False
# dongsihuan_aq False
# gucheng_aq False
# donggaocun_aq False
# pinggu_aq False
# mentougou_aq False
# miyun_aq False
# nongzhanguan_aq False
# yufa_aq False
# daxing_aq False
# yongdingmennei_aq False
# qianmen_aq False
# beibuxinqu_aq False
# nansanhuan_aq False
# yongledian_aq False
# tongzhou_aq False
# yanqin_aq False
# yungang_aq False

# %% [markdown]
# #### 3.2 整体缺失

# %% [markdown]
# 不同站点的整体缺失值也很一致，都是三月底的数据，说明 meo 的数据还是比较全的

# %%
for station in bj_meo_stations.keys() :
    df = bj_meo_stations[station].copy()
    
    min_time = df.index.min()
    max_time = df.index.max()

    min_time = datetime.datetime.strptime(min_time, '%Y-%m-%d %H:%M:%S')
    max_time = datetime.datetime.strptime(max_time, '%Y-%m-%d %H:%M:%S')
    delta_all = max_time - min_time
    
    all_length = delta_all.total_seconds()/3600 + 1
    real_length = df.shape[0]
    # print("在空气质量数据时间段内，总共应该有 %d 个小时节点。" %(all_length))
    # print("实际的时间节点数是 ", real_length)
    print("%s 缺失时间节点数量是 %d" %(station, all_length-real_length))
# Out:
# miyunshuiku_aq 缺失时间节点数量是 121
# wanliu_aq 缺失时间节点数量是 121
# guanyuan_aq 缺失时间节点数量是 121
# fengtaihuayuan_aq 缺失时间节点数量是 121
# huairou_aq 缺失时间节点数量是 121
# liulihe_aq 缺失时间节点数量是 121
# wanshouxigong_aq 缺失时间节点数量是 121
# yizhuang_aq 缺失时间节点数量是 121
# fangshan_aq 缺失时间节点数量是 121
# zhiwuyuan_aq 缺失时间节点数量是 121
# pingchang_aq 缺失时间节点数量是 121
# dingling_aq 缺失时间节点数量是 121
# xizhimenbei_aq 缺失时间节点数量是 121
# aotizhongxin_aq 缺失时间节点数量是 122
# tiantan_aq 缺失时间节点数量是 121
# dongsi_aq 缺失时间节点数量是 121
# badaling_aq 缺失时间节点数量是 121
# shunyi_aq 缺失时间节点数量是 121
# dongsihuan_aq 缺失时间节点数量是 121
# gucheng_aq 缺失时间节点数量是 121
# donggaocun_aq 缺失时间节点数量是 121
# pinggu_aq 缺失时间节点数量是 121
# mentougou_aq 缺失时间节点数量是 122
# miyun_aq 缺失时间节点数量是 121
# nongzhanguan_aq 缺失时间节点数量是 121
# yufa_aq 缺失时间节点数量是 121
# daxing_aq 缺失时间节点数量是 121
# yongdingmennei_aq 缺失时间节点数量是 121
# qianmen_aq 缺失时间节点数量是 121
# beibuxinqu_aq 缺失时间节点数量是 121
# nansanhuan_aq 缺失时间节点数量是 121
# yongledian_aq 缺失时间节点数量是 121
# tongzhou_aq 缺失时间节点数量是 121
# yanqin_aq 缺失时间节点数量是 121
# yungang_aq 缺失时间节点数量是 121

# %% [markdown]
# #### 3.3 整体缺失补充

# %%
for station in bj_meo_stations.keys() :
    df = bj_meo_stations[station].copy()
    print(station, df.shape)
# Out:
# miyunshuiku_aq (11351, 5)
# wanliu_aq (11351, 5)
# guanyuan_aq (11351, 5)
# fengtaihuayuan_aq (11351, 5)
# huairou_aq (11351, 5)
# liulihe_aq (11351, 5)
# wanshouxigong_aq (11351, 5)
# yizhuang_aq (11351, 5)
# fangshan_aq (11351, 5)
# zhiwuyuan_aq (11351, 5)
# pingchang_aq (11351, 5)
# dingling_aq (11351, 5)
# xizhimenbei_aq (11351, 5)
# aotizhongxin_aq (11350, 5)
# tiantan_aq (11351, 5)
# dongsi_aq (11351, 5)
# badaling_aq (11351, 5)
# shunyi_aq (11351, 5)
# dongsihuan_aq (11351, 5)
# gucheng_aq (11351, 5)
# donggaocun_aq (11351, 5)
# pinggu_aq (11351, 5)
# mentougou_aq (11350, 5)
# miyun_aq (11351, 5)
# nongzhanguan_aq (11351, 5)
# yufa_aq (11351, 5)
# daxing_aq (11351, 5)
# yongdingmennei_aq (11351, 5)
# qianmen_aq (11351, 5)
# beibuxinqu_aq (11351, 5)
# nansanhuan_aq (11351, 5)
# yongledian_aq (11351, 5)
# tongzhou_aq (11351, 5)
# yanqin_aq (11351, 5)
# yungang_aq (11351, 5)

# %%
delta = datetime.timedelta(hours=1)

for station in bj_meo_stations.keys() :
    df = bj_meo_stations[station].copy()
    nan_series = pd.Series({key:np.nan for key in df.columns})
    
    min_time = df.index.min()
    max_time = df.index.max()

    min_time = datetime.datetime.strptime(min_time, '%Y-%m-%d %H:%M:%S')
    max_time = datetime.datetime.strptime(max_time, '%Y-%m-%d %H:%M:%S')

    time = min_time
    while time <=  max_time :
        time_str = datetime.date.strftime(time, '%Y-%m-%d %H:%M:%S')
        if time_str not in df.index : 
            df.loc[time_str] = nan_series
        time += delta
    
    bj_meo_stations[station] = df
    
    print("%s : length of data is %d" %(station, df.shape[0]))
# Out:
# miyunshuiku_aq : length of data is 11472
# wanliu_aq : length of data is 11472
# guanyuan_aq : length of data is 11472
# fengtaihuayuan_aq : length of data is 11472
# huairou_aq : length of data is 11472
# liulihe_aq : length of data is 11472
# wanshouxigong_aq : length of data is 11472
# yizhuang_aq : length of data is 11472
# fangshan_aq : length of data is 11472
# zhiwuyuan_aq : length of data is 11472
# pingchang_aq : length of data is 11472
# dingling_aq : length of data is 11472
# xizhimenbei_aq : length of data is 11472
# aotizhongxin_aq : length of data is 11472
# tiantan_aq : length of data is 11472
# dongsi_aq : length of data is 11472
# badaling_aq : length of data is 11472
# shunyi_aq : length of data is 11472
# dongsihuan_aq : length of data is 11472
# gucheng_aq : length of data is 11472
# donggaocun_aq : length of data is 11472
# pinggu_aq : length of data is 11472
# mentougou_aq : length of data is 11472
# miyun_aq : length of data is 11472
# nongzhanguan_aq : length of data is 11472
# yufa_aq : length of data is 11472
# daxing_aq : length of data is 11472
# yongdingmennei_aq : length of data is 11472
# qianmen_aq : length of data is 11472
# beibuxinqu_aq : length of data is 11472
# nansanhuan_aq : length of data is 11472
# yongledian_aq : length of data is 11472
# tongzhou_aq : length of data is 11472
# yanqin_aq : length of data is 11472
# yungang_aq : length of data is 11472

# %% [markdown]
# #### 3.4 风向缺失值处理
# - 暂时使用 0 替换缺失的风向

# %%
for station in bj_meo_stations.keys():
    df = bj_meo_stations[station].copy()
    df.replace(999017,0, inplace=True)
    bj_meo_stations[station] = df

# %% [markdown]
# #### 3.5 拼成整表，并保存

# %%
bj_meo_stations_merged = pd.concat(list(bj_meo_stations.values()), axis=1)

# %%
bj_meo_stations_merged.shape
# Out:
# (11472, 175)

# %%
bj_meo_stations_merged.sort_index(inplace=True)

# %%
bj_meo_stations_merged.to_csv("data/bj_meo_data.csv")

# %% [markdown]
# 需要将 `bj_meo_data.csv`左上角位置的空格补上 "time"

# %% [markdown]
# ### Changelog
# - 0425 v0
#     - 天气数据的缺失值补全
#     - 将数据保存到 `data/bj_meo_data.csv`中
