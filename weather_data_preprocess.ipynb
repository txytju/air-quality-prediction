# %% [markdown]
# - 时间跨度
#     - 历史数据中包含`('2017-01-01 00:00:00', '2018-03-27 05:00:00')`的天气数据
#     - API 下载数据中包含 `'2017-04-01 00:00:00'` 以后的数据
#     - 拟使用四月的数据作为 dev set，

# %%
import datetime
import pandas as pd
from utils.weather_data_util import load_bj_grid_meo_data

# %%
bj_grid_meo_dataset, stations, bj_meo_stations = load_bj_grid_meo_data()

# %% [markdown]
# - `bj_meo_stations` 中的每一个 value 都是一个 `meo station` 对应的天气数据
# - 上述数据中不存在重复的日期

# %%
for station in bj_meo_stations.keys():
    df = bj_meo_stations[station]

    min_time = df.index.min()
    max_time = df.index.max()

    min_time = datetime.datetime.strptime(min_time, '%Y-%m-%d %H:%M:%S')
    max_time = datetime.datetime.strptime(max_time, '%Y-%m-%d %H:%M:%S')
    delta_all = max_time - min_time
    
    all_hours = delta_all.total_seconds()/3600 + 1
    real_hours = df.shape[0]
    print("在空气质量数据时间段内，总共应该有 %d 个小时节点。" %(all_hours))
    print("实际的时间节点数是 %d" %(real_hours))
    print("缺失时间节点数量是 %d" %(all_hours - real_hours))
# Out:
# 在空气质量数据时间段内，总共应该有 11472 个小时节点。
# 实际的时间节点数是 2156
# 缺失时间节点数量是 9316
# 在空气质量数据时间段内，总共应该有 11472 个小时节点。
# 实际的时间节点数是 2156
# 缺失时间节点数量是 9316
# 在空气质量数据时间段内，总共应该有 11472 个小时节点。
# 实际的时间节点数是 2156
# 缺失时间节点数量是 9316
# 在空气质量数据时间段内，总共应该有 11472 个小时节点。
# 实际的时间节点数是 2155
# 缺失时间节点数量是 9317
# 在空气质量数据时间段内，总共应该有 11472 个小时节点。
# 实际的时间节点数是 2155
# 缺失时间节点数量是 9317
# 在空气质量数据时间段内，总共应该有 11472 个小时节点。
# 实际的时间节点数是 2156
# 缺失时间节点数量是 9316
# 在空气质量数据时间段内，总共应该有 11472 个小时节点。
# 实际的时间节点数是 2156
# 缺失时间节点数量是 9316
# 在空气质量数据时间段内，总共应该有 11472 个小时节点。
# 实际的时间节点数是 2155
# 缺失时间节点数量是 9317
# 在空气质量数据时间段内，总共应该有 11472 个小时节点。
# 实际的时间节点数是 2156
# 缺失时间节点数量是 9316
# 在空气质量数据时间段内，总共应该有 11472 个小时节点。
# 实际的时间节点数是 2156
# 缺失时间节点数量是 9316
# 在空气质量数据时间段内，总共应该有 11472 个小时节点。
# 实际的时间节点数是 2156
# 缺失时间节点数量是 9316
# 在空气质量数据时间段内，总共应该有 11472 个小时节点。
# 实际的时间节点数是 2156
# 缺失时间节点数量是 9316
# 在空气质量数据时间段内，总共应该有 11472 个小时节点。
# 实际的时间节点数是 2156
# 缺失时间节点数量是 9316
# 在空气质量数据时间段内，总共应该有 11472 个小时节点。
# 实际的时间节点数是 2156
# 缺失时间节点数量是 9316
# 在空气质量数据时间段内，总共应该有 11472 个小时节点。
# 实际的时间节点数是 2156
# ...

# %%
bj_grid_meo_dataset_1 = pd.read_csv("./KDD_CUP_2018/Beijing/grid_meo/Beijing_historical_meo_grid.csv")

# %%
bj_grid_meo_dataset_1[bj_grid_meo_dataset_1["stationName"] == 'beijing_grid_000'].shape
# Out:
# (1611, 7)
