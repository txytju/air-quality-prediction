# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({"A":[1,np.nan, np.nan],"B":[1,2,np.nan]})

# %%
df.fillna(method='ffill', inplace=True)

# %%
df
# Out:
#      A    B
# 0  1.0  1.0
# 1  1.0  2.0
# 2  1.0  2.0
