# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
from aq_data_preprocess import aq_data_preprocess

# %%
aq_data_preprocess(city="bj")
# Out:
# 完成对 bj 空气质量数据的预处理！

# %%
from weather_data_preprocess import meo_data_preprocess

# %%
meo_data_preprocess()
# Out:
# pinggu_aq 重复数量 : 0
# dingling_aq 重复数量 : 0
# yizhuang_aq 重复数量 : 0
# yongdingmennei_aq 重复数量 : 0
# fangshan_aq 重复数量 : 0
# tiantan_aq 重复数量 : 0
# donggaocun_aq 重复数量 : 0
# beibuxinqu_aq 重复数量 : 0
# qianmen_aq 重复数量 : 0
# dongsihuan_aq 重复数量 : 0
# shunyi_aq 重复数量 : 0
# yufa_aq 重复数量 : 0
# fengtaihuayuan_aq 重复数量 : 0
# huairou_aq 重复数量 : 0
# aotizhongxin_aq 重复数量 : 0
# yungang_aq 重复数量 : 0
# tongzhou_aq 重复数量 : 0
# xizhimenbei_aq 重复数量 : 0
# badaling_aq 重复数量 : 0
# nongzhanguan_aq 重复数量 : 0
# pingchang_aq 重复数量 : 0
# dongsi_aq 重复数量 : 0
# liulihe_aq 重复数量 : 0
# wanliu_aq 重复数量 : 0
# mentougou_aq 重复数量 : 0
# wanshouxigong_aq 重复数量 : 0
# gucheng_aq 重复数量 : 0
# miyun_aq 重复数量 : 0
# yanqin_aq 重复数量 : 0
# daxing_aq 重复数量 : 0
# zhiwuyuan_aq 重复数量 : 0
# yongledian_aq 重复数量 : 0
# miyunshuiku_aq 重复数量 : 0
# nansanhuan_aq 重复数量 : 0
# guanyuan_aq 重复数量 : 0
# pinggu_aq 缺失时间节点数量是 121
# dingling_aq 缺失时间节点数量是 121
# yizhuang_aq 缺失时间节点数量是 121
# yongdingmennei_aq 缺失时间节点数量是 121
# fangshan_aq 缺失时间节点数量是 121
# tiantan_aq 缺失时间节点数量是 121
# ...

# %%
from train_dev_set_split import train_dev_set_split

# %%
train_dev_set_split(city="bj")
# Out:
# (11458, 210) (11472, 175)
# 2017-01-01 00:00:00 2018-04-23 23:00:00
# 2017-01-01 14:00:00 2018-04-23 23:00:00
# (552, 175)
# (552, 210)
# (10873, 175)
# (10873, 210)

# %%
import pandas as pd

# %%
city="bj"

# %%
meo = pd.read_csv("./test/%s_meo_norm_data.csv" %(city))

# %%
meo.head()
# Out:
#             Unnamed: 0  pinggu_aq_temperature  pinggu_aq_pressure  \
# 0  2017-01-01 00:00:00              -1.292660            0.778560
# 1  2017-01-01 01:00:00              -1.114788            0.761821
# 2  2017-01-01 02:00:00              -0.937764            0.746128
# 3  2017-01-01 03:00:00              -0.759892            0.730435
# 4  2017-01-01 04:00:00              -0.690437            0.669755
#
#    pinggu_aq_humidity  pinggu_aq_wind_direction  pinggu_aq_wind_speed/kph  \
# 0            0.713501                  0.792775                 -1.084373
# 1            0.359881                  0.709084                 -0.994589
# 2            0.006737                  0.652300                 -0.893378
# 3           -0.346406                  0.612164                 -0.788902
# 4           -0.414080                  0.588406                 -0.801961
#
#    dingling_aq_temperature  dingling_aq_pressure  dingling_aq_humidity  \
# ...

# %%
meo.rename(index=str, columns={'Unnamed: 0':'time'}, inplace=True)

# %%
meo
# Out:
#                       time  pinggu_aq_temperature  pinggu_aq_pressure  \
# 0      2017-01-01 00:00:00              -1.292660            0.778560
# 1      2017-01-01 01:00:00              -1.114788            0.761821
# 2      2017-01-01 02:00:00              -0.937764            0.746128
# 3      2017-01-01 03:00:00              -0.759892            0.730435
# 4      2017-01-01 04:00:00              -0.690437            0.669755
# 5      2017-01-01 05:00:00              -0.620983            0.609076
# 6      2017-01-01 06:00:00              -0.550681            0.548396
# 7      2017-01-01 07:00:00              -0.714154            0.541072
# 8      2017-01-01 08:00:00              -0.876779            0.534795
# 9      2017-01-01 09:00:00              -1.040252            0.527472
# 10     2017-01-01 10:00:00              -1.037711            0.543165
# 11     2017-01-01 11:00:00              -1.035170            0.558858
# ...

# %%
from train_seq2seq import train_and_dev
# Out:
# /home/cvdev/tf/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
model_preds, model_name = train_and_dev(city='bj',pre_days=5, gap=0, loss_function="L2")
# Out:
# Training losses:
# loss after 0/200 iteractions : 107.949
# Checkpoint saved at:  ./result/multi_variable_model_results/5 pre_days, 0 gap, L2 loss_function, multivariate_0_iteractions
# loss after 10/200 iteractions : 56.883
# Checkpoint saved at:  ./result/multi_variable_model_results/5 pre_days, 0 gap, L2 loss_function, multivariate_10_iteractions
# loss after 20/200 iteractions : 42.698
# Checkpoint saved at:  ./result/multi_variable_model_results/5 pre_days, 0 gap, L2 loss_function, multivariate_20_iteractions
# loss after 30/200 iteractions : 41.841
# Checkpoint saved at:  ./result/multi_variable_model_results/5 pre_days, 0 gap, L2 loss_function, multivariate_30_iteractions
# loss after 40/200 iteractions : 41.840
# Checkpoint saved at:  ./result/multi_variable_model_results/5 pre_days, 0 gap, L2 loss_function, multivariate_40_iteractions
# loss after 50/200 iteractions : 36.799
# ...

# %%
model_preds.shape
# Out:
# (17, 48, 105)

# %%
model_name
# Out:
# '5 pre_days, 0 gap, L2 loss_function, multivariate_70_iteractions'

# %%
x = {0: [1.0954538605735393], 130: [0.7845674821397286], 260: [0.7741945718914706], 390: [0.7971361107295963], 10: [0.9416291208381316], 140: [0.7690279554805829], 270: [0.7793703186939384], 400: [0.7929832354857481], 20: [0.8710264147639002], 150: [0.7608054337749108], 280: [0.7745445761642601], 410: [0.8081291714751762], 30: [0.8250510091617802], 160: [0.7586639603829547], 290: [0.7853249127945054], 420: [0.7890741255166817], 40: [0.8770401805169089], 170: [0.7942076450237892], 300: [0.8063001560524206], 430: [0.8118276570043041], 50: [0.8116236317102878], 180: [0.759570367402665], 310: [0.7962732601977863], 440: [0.8157972015949186], 60: [0.8306268775500281], 190: [0.7838293344834023], 320: [0.8070504367591453], 450: [0.7935444737392655], 70: [0.8172179323271221], 200: [0.7771403503395592], 330: [0.7839155120128747], 460: [0.7988917288321288], 80: [0.798718247259342], 210: [0.7856719306340687], 340: [0.791475218377683], 470: [0.7821436421500465], 90: [0.7965328024352444], 220: [0.7729088469296675], 350: [0.7819101613740478], 480: [0.7913020222542043], 100: [0.7877386423760198], 230: [0.7618692289237046], 360: [0.7810644464163361], 490: [0.7990681740365445], 110: [0.7960681680622682], 240: [0.7686108047437474], 370: [0.7868897326890076], 120: [0.7696997803007807], 250: [0.7736152303866044], 380: [0.810490244472351]}

# %%
min(list(x.values())) # 8
# Out:
# [0.7142719257096753]

# %%
x = {0: [1.0900041803425957], 130: [0.7817252713115078], 260: [0.7923725809461504], 390: [0.799238295396223], 10: [0.8306985045414297], 140: [0.7879377556608265], 270: [0.8420178478854684], 400: [0.8348106719175834], 20: [0.7947862337018647], 150: [0.8449147096992117], 280: [0.8475776379209614], 410: [0.7938491022014522], 30: [0.7797763953147137], 160: [0.8010474119153195], 290: [0.8268343548624028], 420: [0.8349989847529818], 40: [0.7964310257491104], 170: [0.7974233534153407], 300: [0.8385408853376387], 430: [0.7880497959401112], 50: [0.7593188462573406], 180: [0.8214659805625663], 310: [0.800201366078755], 440: [0.822985988558923], 60: [0.8119319888567079], 190: [0.8828407077294572], 320: [0.8036745556662778], 450: [0.7966666626127579], 70: [0.7824170331007999], 200: [0.8026050281240829], 330: [0.8256547503322214], 460: [0.8497618626786994], 80: [0.8140325478222136], 210: [0.8250734855886752], 340: [0.8056346334445431], 470: [0.8079926888645533], 90: [0.7563168316738007], 220: [0.8066059317519905], 350: [0.8340752827149759], 480: [0.8091717785948619], 100: [0.8122916982938587], 230: [0.803749908626182], 360: [0.8160882459433044], 490: [0.8339195508100965], 110: [0.8358541842838939], 240: [0.8078419853978004], 370: [0.7867854951866157], 120: [0.7861289439310061], 250: [0.8650817266105189], 380: [0.8459876064803669]}

# %%
min(list(x.values())) # 9
# Out:
# [0.7563168316738007]

# %%
import pandas as pd
import numpy as np

# %%
from seq2seq.seq2seq_data_util import generate_dev_set

# %%
city = 'bj'

# %%
station_list = ['dongsi_aq','tiantan_aq','guanyuan_aq','wanshouxigong_aq','aotizhongxin_aq',
            'nongzhanguan_aq','wanliu_aq','beibuxinqu_aq','zhiwuyuan_aq','fengtaihuayuan_aq',
            'yungang_aq','gucheng_aq','fangshan_aq','daxing_aq','yizhuang_aq','tongzhou_aq',
            'shunyi_aq','pingchang_aq','mentougou_aq','pinggu_aq','huairou_aq','miyun_aq',
            'yanqin_aq','dingling_aq','badaling_aq','miyunshuiku_aq','donggaocun_aq',
            'yongledian_aq','yufa_aq','liulihe_aq','qianmen_aq','yongdingmennei_aq',
            'xizhimenbei_aq','nansanhuan_aq','dongsihuan_aq']            
X_aq_list = ["PM2.5","PM10","O3","CO","SO2","NO2"]  
y_aq_list = ["PM2.5","PM10","O3"]
X_meo_list = ["temperature","pressure","humidity","direction","speed/kph"]

# %%
X_dev_batch, y_dev_batch = generate_dev_set(city="bj", 
                 station_list=station_list, 
                 X_aq_list=X_aq_list, 
                 y_aq_list=y_aq_list, 
                 X_meo_list=X_meo_list, 
                 pre_days=7, 
                 gap=24)

# %%
X_dev_batch.shape
# Out:
# (14, 144, 385)

# %%
y_dev_batch.shape
# Out:
# (14, 48, 105)

# %%
import pandas as pd

# %%
from ld_aq_data_preprocess import aq_data_preprocess

# %%
df_merged = aq_data_preprocess()
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:2862: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# 最早的日期： 2017-01-01 00:00:00
# 最晚的日期： 2018-04-01 00:00:00

# %%
pd.isnull(df_merged).any().any()
# Out:
# False

# %%
# 看哪些全是 0 舍弃

# %%
y = df_merged.mean(axis=1)

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
plt.plot(y.values)

# %%
from utils.weather_data_util import load_ld_grid_meo_data

# %%
ld_grid_meo_dataset, stations, ld_meo_stations = load_ld_grid_meo_data()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-9403fb9eeabc> in <module>()
# ----> 1 ld_grid_meo_dataset, stations, ld_meo_stations = load_ld_grid_meo_data()
#
# TypeError: load_ld_grid_meo_data() missing 1 required positional argument: 'useful_stations'

# %%
import requests
from datetime import datetime

now = datetime.now()

year = now.year
month = now.month
day = now.day
hour = now.hour

# %%
now
# Out:
# datetime.datetime(2018, 4, 29, 12, 14, 1, 357888)

# %%
print(year, month, day, hour)
# Out:
# 2018 4 29 12

# %%
import pandas as pd
import os

# %%
path_to_ld_aq = "./KDD_CUP_2018/London/aq/"
ld_csv_list  = os.listdir(path_to_ld_aq)

print(ld_csv_list)

# 读取 某个特定文件夹中的所有文件名
# ld_csv_list = ["./KDD_CUP_2018/London/aq/London_historical_aqi_forecast_stations_20180331.csv",
#                "./KDD_CUP_2018/London/aq/London_historical_aqi_other_stations_20180331.csv"]

ld_aq_datas = []

for csv in ld_csv_list :
    path_to_file = path_to_ld_aq + csv
    print(path_to_file)
    ld_aq_data = pd.read_csv(path_to_file)

    # 处理
    # 去掉伦敦多余的数字列
    for column_name in ld_aq_data.columns :
        if 'Unnamed:' in column_name : 
            ld_aq_data.drop(column_name, axis=1, inplace=True)

    # 统一表头格式：将伦敦的表头换成北京的表头格式
    # 伦敦的表头自己也不统一
    name_pair = {}

    if 'station_id' in ld_aq_data.columns :
        name_pair['MeasurementDateGMT'] = 'utc_time'
        name_pair['station_id'] = 'stationId'
        # name_pair = {'MeasurementDateGMT':'utc_time', 'station_id':'stationId'}
    elif 'Station_ID' in ld_aq_data.columns :  
        name_pair['MeasurementDateGMT'] = 'utc_time'
        name_pair['Station_ID'] = 'stationId'

    if "time" in ld_aq_data.columns :
        name_pair["time"] = "utc_time"

    flag = False
    for column in ld_aq_data.columns : 
        if "_Concentration" in column :
            flag = True
    if flag :
        name_pair["PM25_Concentration"] = "PM2.5 (ug/m3)"
        name_pair["PM10_Concentration"] = "PM10 (ug/m3)"
        name_pair["NO2_Concentration"] = "NO2 (ug/m3)"
        ld_aq_data.drop("CO_Concentration", axis=1, inplace=True)
        ld_aq_data.drop("O3_Concentration", axis=1, inplace=True)
        ld_aq_data.drop("SO2_Concentration", axis=1, inplace=True)

    if "id" in ld_aq_data.columns : 
        ld_aq_data.drop("id", axis=1, inplace=True)

    ld_aq_data.rename(index=str, columns=name_pair, inplace=True)

    # 去掉空值行
    # ld_aq_data = ld_aq_data[pd.isnull(ld_aq_data["stationId"]) != True]


    print(ld_aq_data.columns)

    ld_aq_datas.append(ld_aq_data)

ld_aq_df = pd.concat(ld_aq_datas, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-45f833b21cad> in <module>()
#       1 path_to_ld_aq = "./KDD_CUP_2018/London/aq/"
# ----> 2 ld_csv_list  = os.listdir(path_to_ld_aq)
#       3
#       4 print(ld_csv_list)
#       5
#
# NameError: name 'os' is not defined

# %%
ld_aq_df.head()
# Out:
#    NO2 (ug/m3)  PM10 (ug/m3)  PM2.5 (ug/m3) stationId       utc_time
# 0         36.6          44.4           40.0       CD1  2017/1/1 0:00
# 1         46.2          34.4           31.6       CD1  2017/1/1 1:00
# 2         38.3          28.1           24.7       CD1  2017/1/1 2:00
# 3         32.8          24.5           21.2       CD1  2017/1/1 3:00
# 4         28.1          23.0           24.9       CD1  2017/1/1 4:00

# %%
from utils.data_util import load_city_aq_data

# %%
ld_aq_dataset, stations, ld_aq_stations, ld_aq_stations_merged = load_city_aq_data(ld_aq_df)
# Out:
# (11575, 3)
# (11574, 3)
# (10920, 3)
# (10920, 3)
# (11581, 3)
# (10181, 3)
# (11597, 3)
# (11575, 3)
# (11597, 3)
# (11575, 3)
# (10920, 3)
# (11575, 3)
# (11575, 3)
# (11583, 3)
# (11575, 3)
# (11572, 3)
# (11581, 3)
# (11575, 3)
# (11575, 3)
# (10921, 3)
# (11597, 3)
# (11575, 3)
# (10921, 3)
# (11574, 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-65b77befc96b> in <module>()
# ----> 1 ld_aq_dataset, stations, ld_aq_stations, ld_aq_stations_merged = load_city_aq_data(ld_aq_df)
#
# /notebooks/KDD_Cup_2018/utils/data_util.py in load_city_aq_data(aq_df)
#     167
#     168         # merge data of different stations into one df
# --> 169         aq_stations_merged = pd.concat(list(aq_stations.values()), axis=1)
#     170         # add a column of (0,1,2,3,...) to count
#     171         length = aq_stations_merged.shape[0]
#
# ...

# %%
from aq_data_preprocess import aq_data_preprocess

# %%
aq_data_preprocess("ld")
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:2862: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /notebooks/KDD_Cup_2018/aq_data_preprocess.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_merged.loc[hour] = for_row + (for_step/all_steps) * delata_values
# /notebooks/KDD_Cup_2018/aq_data_preprocess.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_merged.loc[hour] = nan_series
# /notebooks/KDD_Cup_2018/aq_data_preprocess.py:207: SettingWithCopyWarning:
# ...

# %%
from utils.weather_data_util import load_bj_grid_meo_data

# %%
bj_near_stations = {'aotizhongxin_aq': 'beijing_grid_304',
 'badaling_aq': 'beijing_grid_224',
 'beibuxinqu_aq': 'beijing_grid_263',
 'daxing_aq': 'beijing_grid_301',
 'dingling_aq': 'beijing_grid_265',
 'donggaocun_aq': 'beijing_grid_452',
 'dongsi_aq': 'beijing_grid_303',
 'dongsihuan_aq': 'beijing_grid_324',
 'fangshan_aq': 'beijing_grid_238',
 'fengtaihuayuan_aq': 'beijing_grid_282',
 'guanyuan_aq': 'beijing_grid_282',
 'gucheng_aq': 'beijing_grid_261',
 'huairou_aq': 'beijing_grid_349',
 'liulihe_aq': 'beijing_grid_216',
 'mentougou_aq': 'beijing_grid_240',
 'miyun_aq': 'beijing_grid_392',
 'miyunshuiku_aq': 'beijing_grid_414',
 'nansanhuan_aq': 'beijing_grid_303',
 'nongzhanguan_aq': 'beijing_grid_324',
 'pingchang_aq': 'beijing_grid_264',
 'pinggu_aq': 'beijing_grid_452',
 'qianmen_aq': 'beijing_grid_303',
 'shunyi_aq': 'beijing_grid_368',
 'tiantan_aq': 'beijing_grid_303',
 'tongzhou_aq': 'beijing_grid_366',
 'wanliu_aq': 'beijing_grid_283',
 'wanshouxigong_aq': 'beijing_grid_303',
 'xizhimenbei_aq': 'beijing_grid_283',
 'yanqin_aq': 'beijing_grid_225',
 'yizhuang_aq': 'beijing_grid_323',
 'yongdingmennei_aq': 'beijing_grid_303',
 'yongledian_aq': 'beijing_grid_385',
 'yufa_aq': 'beijing_grid_278',
 'yungang_aq': 'beijing_grid_239',
 'zhiwuyuan_aq': 'beijing_grid_262'}

# %%
bj_grid_meo_dataset, stations, bj_meo_stations = load_bj_grid_meo_data(bj_near_stations)
# Out:
# ./KDD_CUP_2018/Beijing/grid_meo/bj_grid_2018-04-8-0_2018-04-23-23.csv
# Index(['id', 'station_id', 'time', 'weather', 'temperature', 'pressure',
#        'humidity', 'wind_direction', 'wind_speed'],
#       dtype='object')
# ./KDD_CUP_2018/Beijing/grid_meo/bj_grid_2018-04-24-0_2018-04-24-23.csv
# Index(['id', 'station_id', 'time', 'weather', 'temperature', 'pressure',
#        'humidity', 'wind_direction', 'wind_speed'],
#       dtype='object')
# ./KDD_CUP_2018/Beijing/grid_meo/Beijing_historical_meo_grid.csv
# Index(['stationName', 'longitude', 'latitude', 'utc_time', 'temperature',
#        'pressure', 'humidity', 'wind_direction', 'wind_speed/kph'],
#       dtype='object')

# %%
bj_grid_meo_dataset
# Out:
#                           stationName  temperature   pressure  humidity  \
# time
# 2018-04-08 00:00:00  beijing_grid_000         7.00   971.7875     28.00
# 2018-04-08 00:00:00  beijing_grid_001         7.00   957.9635     27.00
# 2018-04-08 00:00:00  beijing_grid_002        10.00   944.1395     27.00
# 2018-04-08 00:00:00  beijing_grid_003        10.00   928.3123     26.00
# 2018-04-08 00:00:00  beijing_grid_004        10.00   910.4819     27.00
# 2018-04-08 00:00:00  beijing_grid_005        10.00   892.6515     28.00
# 2018-04-08 00:00:00  beijing_grid_006        10.00   874.1427     30.00
# 2018-04-08 00:00:00  beijing_grid_007        10.00   855.6339     34.00
# 2018-04-08 00:00:00  beijing_grid_008         3.41   848.3987     36.00
# 2018-04-08 00:00:00  beijing_grid_009         3.09   852.4371     37.00
# 2018-04-08 00:00:00  beijing_grid_010         0.00   856.4755     39.00
# 2018-04-08 00:00:00  beijing_grid_011         0.00   867.6051     40.00
# ...

# %%
import os
import pandas as pd

# %%
path_to_bj_meo = "./KDD_CUP_2018/Beijing/grid_meo/"
bj_csv_list  = os.listdir(path_to_bj_meo)

bj_meo_datas = []

for csv in bj_csv_list :
    if csv != '.DS_Store' and not csv.startswith("._"):
        path_to_file = path_to_bj_meo + csv
        print(path_to_file)
        bj_meo_data = pd.read_csv(path_to_file)
        print(bj_meo_data.columns)

        # 去掉多余信息
        if "longitude" in bj_meo_data.columns :
            bj_meo_data.drop("longitude", axis=1, inplace=True)
        if "latitude" in bj_meo_data.columns :    
            bj_meo_data.drop("latitude", axis=1, inplace=True)
        if "id" in bj_meo_data.columns :
            bj_meo_data.drop("id", axis=1, inplace=True)
        if "weather" in bj_meo_data.columns :
            bj_meo_data.drop("weather", axis=1, inplace=True)

        name_pairs = {}
        if "station_id" in bj_meo_data.columns :
            name_pairs["station_id"] = "stationName"
        if "time" in bj_meo_data.columns :
            name_pairs["time"] = "utc_time"
        if "wind_speed/kph" in bj_meo_data.columns :
            name_pairs["wind_speed/kph"] = "wind_speed"

        bj_meo_data.rename(index=str, columns=name_pairs, inplace=True)
        bj_meo_datas.append(bj_meo_data)
# Out:
# ./KDD_CUP_2018/Beijing/grid_meo/bj_grid_2018-04-8-0_2018-04-23-23.csv
# Index(['id', 'station_id', 'time', 'weather', 'temperature', 'pressure',
#        'humidity', 'wind_direction', 'wind_speed'],
#       dtype='object')
# ./KDD_CUP_2018/Beijing/grid_meo/bj_grid_2018-04-24-0_2018-04-24-23.csv
# Index(['id', 'station_id', 'time', 'weather', 'temperature', 'pressure',
#        'humidity', 'wind_direction', 'wind_speed'],
#       dtype='object')
# ./KDD_CUP_2018/Beijing/grid_meo/Beijing_historical_meo_grid.csv
# Index(['stationName', 'longitude', 'latitude', 'utc_time', 'temperature',
#        'pressure', 'humidity', 'wind_direction', 'wind_speed/kph'],
#       dtype='object')

# %%
bj_meo_datas[0].head()
# Out:
#         stationName       utc_time  temperature  pressure  humidity  \
# 0  beijing_grid_000  2018/4/8 0:00          7.0  971.7875        28
# 1  beijing_grid_001  2018/4/8 0:00          7.0  957.9635        27
# 2  beijing_grid_002  2018/4/8 0:00         10.0  944.1395        27
# 3  beijing_grid_003  2018/4/8 0:00         10.0  928.3123        26
# 4  beijing_grid_004  2018/4/8 0:00         10.0  910.4819        27
#
#    wind_direction  wind_speed
# 0           36.90        5.19
# 1           20.71        3.24
# 2          336.56        2.08
# 3          316.30        3.84
# 4          322.44        7.12

# %%
bj_meo_datas[1].head()
# Out:
#         stationName             utc_time  temperature  pressure  humidity  \
# 0  beijing_grid_000  2018-04-24 00:00:00         17.0  983.4898      53.0
# 1  beijing_grid_001  2018-04-24 00:00:00         17.0  969.7682      52.0
# 2  beijing_grid_002  2018-04-24 00:00:00          8.0  956.0466      51.0
# 3  beijing_grid_003  2018-04-24 00:00:00          8.0  940.3794      51.0
# 4  beijing_grid_004  2018-04-24 00:00:00          8.0  922.7666      52.0
#
#    wind_direction  wind_speed
# 0          311.91        4.52
# 1          314.83        3.45
# 2          320.38        2.39
# 3          337.51        2.14
# 4          353.39        2.86

# %%
bj_meo_datas[2].head()
# Out:
#         stationName             utc_time  temperature  pressure  humidity  \
# 0  beijing_grid_000  2017-01-01 00:00:00        -5.47    984.73     76.60
# 1  beijing_grid_001  2017-01-01 00:00:00        -5.53    979.33     75.40
# 2  beijing_grid_002  2017-01-01 00:00:00        -5.70    963.14     71.80
# 3  beijing_grid_003  2017-01-01 00:00:00        -5.88    946.94     68.20
# 4  beijing_grid_004  2017-01-01 00:00:00        -5.34    928.80     58.81
#
#    wind_direction  wind_speed
# 0           53.71        3.53
# 1           43.59        3.11
# 2            0.97        2.75
# 3          327.65        3.84
# 4          317.85        6.14

# %%
path_to_ld_meo = "./KDD_CUP_2018/London/grid_meo/"
bj_csv_list  = os.listdir(path_to_ld_meo)
print(bj_csv_list)
# Out:
# ['ld_grid_2018-04-25-0_2018-04-25-23.csv', 'London_historical_meo_grid.csv', '._London_historical_meo_grid.csv']

# %%
bj_meo_datas = []

for csv in bj_csv_list :
    if csv != '.DS_Store' and not csv.startswith("._"):
        path_to_file = path_to_ld_meo + csv
        print(path_to_file)
        bj_meo_data = pd.read_csv(path_to_file)
        print(bj_meo_data.columns)

        # 去掉多余信息
        if "longitude" in bj_meo_data.columns :
            bj_meo_data.drop("longitude", axis=1, inplace=True)
        if "latitude" in bj_meo_data.columns :    
            bj_meo_data.drop("latitude", axis=1, inplace=True)
        if "id" in bj_meo_data.columns :
            bj_meo_data.drop("id", axis=1, inplace=True)
        if "weather" in bj_meo_data.columns :
            bj_meo_data.drop("weather", axis=1, inplace=True)

        name_pairs = {}
        if "station_id" in bj_meo_data.columns :
            name_pairs["station_id"] = "stationName"
        if "time" in bj_meo_data.columns :
            name_pairs["time"] = "utc_time"
        if "wind_speed/kph" in bj_meo_data.columns :
            name_pairs["wind_speed/kph"] = "wind_speed"

        bj_meo_data.rename(index=str, columns=name_pairs, inplace=True)
        bj_meo_datas.append(bj_meo_data)


meo_dataset = pd.concat(bj_meo_datas, ignore_index=True)
# Out:
# ./KDD_CUP_2018/London/grid_meo/ld_grid_2018-04-25-0_2018-04-25-23.csv
# Index(['id', 'station_id', 'time', 'weather', 'temperature', 'pressure',
#        'humidity', 'wind_direction', 'wind_speed'],
#       dtype='object')
# ./KDD_CUP_2018/London/grid_meo/London_historical_meo_grid.csv
# Index(['stationName', 'longitude', 'latitude', 'utc_time', 'temperature',
#        'pressure', 'humidity', 'wind_direction', 'wind_speed/kph'],
#       dtype='object')

# %%
bj_meo_datas[0].head()
# Out:
#        stationName             utc_time  temperature   pressure  humidity  \
# 0  london_grid_000  2018-04-25 00:00:00        10.96  1011.6788      89.0
# 1  london_grid_001  2018-04-25 00:00:00        10.57  1010.4692      90.0
# 2  london_grid_002  2018-04-25 00:00:00        10.17  1009.2596      90.0
# 3  london_grid_003  2018-04-25 00:00:00         9.77  1006.4020      91.0
# 4  london_grid_004  2018-04-25 00:00:00         9.37  1001.8964      93.0
#
#    wind_direction  wind_speed
# 0          268.94       33.10
# 1          270.76       28.64
# 2          273.25       24.21
# 3          276.04       21.80
# 4          278.45       21.39

# %%
bj_meo_datas[1].head()
# Out:
#        stationName             utc_time  temperature  pressure  humidity  \
# 0  london_grid_000  2017-01-01 00:00:00         9.36   1024.81     77.90
# 1  london_grid_001  2017-01-01 00:00:00         9.09   1024.25     78.96
# 2  london_grid_002  2017-01-01 00:00:00         8.30   1022.55     82.13
# 3  london_grid_003  2017-01-01 00:00:00         7.50   1020.86     85.30
# 4  london_grid_004  2017-01-01 00:00:00         6.92   1015.89     88.51
#
#    wind_direction  wind_speed
# 0          250.88       23.74
# 1          249.86       21.81
# 2          245.35       16.08
# 3          235.98       10.55
# 4          228.21       10.97

# %%
meo_dataset
# Out:
#              stationName             utc_time  temperature   pressure  \
# 0        london_grid_000  2018-04-25 00:00:00        10.96  1011.6788
# 1        london_grid_001  2018-04-25 00:00:00        10.57  1010.4692
# 2        london_grid_002  2018-04-25 00:00:00        10.17  1009.2596
# 3        london_grid_003  2018-04-25 00:00:00         9.77  1006.4020
# 4        london_grid_004  2018-04-25 00:00:00         9.37  1001.8964
# 5        london_grid_005  2018-04-25 00:00:00         8.96   997.3908
# 6        london_grid_006  2018-04-25 00:00:00         8.83   996.6036
# 7        london_grid_007  2018-04-25 00:00:00         8.69   995.8164
# 8        london_grid_008  2018-04-25 00:00:00         8.47   996.0340
# 9        london_grid_009  2018-04-25 00:00:00         8.15   997.2564
# 10       london_grid_010  2018-04-25 00:00:00         7.83   998.4788
# 11       london_grid_011  2018-04-25 00:00:00         7.41   996.2964
# ...

# %%
from weather_data_preprocess import meo_data_preprocess

# %%
meo_data_preprocess("bj")
# Out:
# ./KDD_CUP_2018/Beijing/grid_meo/bj_grid_2018-04-8-0_2018-04-23-23.csv
# Index(['id', 'station_id', 'time', 'weather', 'temperature', 'pressure',
#        'humidity', 'wind_direction', 'wind_speed'],
#       dtype='object')
# ./KDD_CUP_2018/Beijing/grid_meo/bj_grid_2018-04-24-0_2018-04-24-23.csv
# Index(['id', 'station_id', 'time', 'weather', 'temperature', 'pressure',
#        'humidity', 'wind_direction', 'wind_speed'],
#       dtype='object')
# ./KDD_CUP_2018/Beijing/grid_meo/Beijing_historical_meo_grid.csv
# Index(['stationName', 'longitude', 'latitude', 'utc_time', 'temperature',
#        'pressure', 'humidity', 'wind_direction', 'wind_speed/kph'],
#       dtype='object')
# daxing_aq 重复数量 : 0
# shunyi_aq 重复数量 : 0
# pinggu_aq 重复数量 : 0
# huairou_aq 重复数量 : 0
# fangshan_aq 重复数量 : 0
# yizhuang_aq 重复数量 : 0
# wanliu_aq 重复数量 : 0
# dongsi_aq 重复数量 : 0
# nansanhuan_aq 重复数量 : 0
# aotizhongxin_aq 重复数量 : 0
# miyunshuiku_aq 重复数量 : 0
# gucheng_aq 重复数量 : 0
# miyun_aq 重复数量 : 0
# ...

# %%
meo_data_preprocess("ld")
# Out:
# ./KDD_CUP_2018/London/grid_meo/ld_grid_2018-04-25-0_2018-04-25-23.csv
# Index(['id', 'station_id', 'time', 'weather', 'temperature', 'pressure',
#        'humidity', 'wind_direction', 'wind_speed'],
#       dtype='object')
# ./KDD_CUP_2018/London/grid_meo/London_historical_meo_grid.csv
# Index(['stationName', 'longitude', 'latitude', 'utc_time', 'temperature',
#        'pressure', 'humidity', 'wind_direction', 'wind_speed/kph'],
#       dtype='object')
# CT2 重复数量 : 0
# GR4 重复数量 : 0
# KC1 重复数量 : 0
# BX9 重复数量 : 0
# CT3 重复数量 : 0
# TD5 重复数量 : 0
# ST5 重复数量 : 0
# CR8 重复数量 : 0
# KF1 重复数量 : 0
# GR9 重复数量 : 0
# CD9 重复数量 : 0
# GN0 重复数量 : 0
# TH4 重复数量 : 0
# MY7 重复数量 : 0
# GN3 重复数量 : 0
# LH0 重复数量 : 0
# BX1 重复数量 : 0
# LW2 重复数量 : 0
# HV1 重复数量 : 0
# CD1 重复数量 : 0
# HR1 重复数量 : 0
# GB0 重复数量 : 0
# RB7 重复数量 : 0
# BL0 重复数量 : 0
# CT2 (10830, 5)
# GR4 (10830, 5)
# KC1 (10830, 5)
# BX9 (10830, 5)
# CT3 (10830, 5)
# TD5 (10830, 5)
# ST5 (10830, 5)
# CR8 (10830, 5)
# KF1 (10830, 5)
# GR9 (10830, 5)
# ...
